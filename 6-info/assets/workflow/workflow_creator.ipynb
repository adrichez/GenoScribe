# %% [markdown]
# <span style="color:#deb66d">
#
# ---
# ---
# ---
# # **CREADOR DE DIAGRAMA DE FLUJO**
# ---
# ---
# ---
#
# </span>

# %% [markdown]
# Lo primero que vamos a hacer es importar las librerías necesarias para trabajar en este notebook:

# %%
# Carga de librerías
from graphviz import Digraph

# %% [markdown]
# $\ $
#
# $\ $
#
# $\ $
#
# <span style="color:#67bb74">
#
# ---
# ---
# ## **Estructura del diagrama de flujo general**
# ---
# ---
#
# </span>

# %%
#-----------------------------------------------------------------------------------------------------------------------------------
# CONFIGURACIÓN DEL GRÁFICO
#-----------------------------------------------------------------------------------------------------------------------------------

dot = Digraph("Pipeline", format="png")
dot.attr(rankdir="TB", nodesep="2", ranksep="2", fontsize="45", pad="2", splines="true", bgcolor="#e1e4eb", dpi="400", size="10,6!")
dot.attr("node", fontsize="40", fontname="Helvetica-Bold", fontcolor="#FFFFFF", margin="1,0.6", style="filled", shape="oval", penwidth="4", fillcolor="#A8DADC")
dot.attr("edge", fontsize="15", color="#1D3557", penwidth="8", arrowhead="normal", fontcolor="#1D3557")




#-----------------------------------------------------------------------------------------------------------------------------------
# NODOS
#-----------------------------------------------------------------------------------------------------------------------------------

# Punto de partida
dot.node("USUARIO", "🧑  Usuario", shape="box", style="filled", fontsize="55", margin="1.8,1", fillcolor="#a23f5d")
dot.node("N1", "📁  Datos de entrada con los que elaborar el informe", shape="note", style="filled", fontsize="42", margin="1.2,0.6", fontcolor="#000000", fillcolor="#dadada")


# Primera decisión: Local vs HPC
dot.node("D1", "¿Dónde quiere ejecutar el análisis?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("LOCAL", "💻  Local", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("HPC", "🖥️  HPC / ☁️  Cloud (cluster)", shape="ellipse", style="filled", fillcolor="#438eac")


# Decisiones dentro de Local
dot.node("D_LOCAL_1", "⚙️  ¿Cómo quiere ejecutar en Local?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("DIRECT_LOCAL", "🖥️  Directo en su ordenador", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("CONTENEDOR_LOCAL", "📦  En un contenedor (recomendado)", shape="ellipse", style="filled", fillcolor="#438eac")

dot.node("D_LOCAL_2", "📦  ¿Qué contenedor usar?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("DOCKER_LOCAL", "🐳  Docker", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("APPTAINER_LOCAL", "🧪  Apptainer", shape="ellipse", style="filled", fillcolor="#438eac")

dot.node("D_LOCAL_3", "🛠️  ¿Cómo quiere interactuar?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("CLI_LOCAL", "⌨️  Terminal (CLI)", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("SHINY_LOCAL", "🖼️  Interfaz gráfica (Shiny)", shape="ellipse", style="filled", fillcolor="#438eac")


# Decisiones dentro HPC/Cloud
dot.node("D_HPC_1", "⚙️  ¿Cómo quiere ejecutar en HPC?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("DIRECT_HPC", "🖥️  Directo en el cluster", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("CONTENEDOR_HPC", "📦  En contenedor (recomendado)", shape="ellipse", style="filled", fillcolor="#438eac")

dot.node("APPTAINER_HPC", "🧪  Apptainer", shape="ellipse", style="filled", fillcolor="#438eac")

dot.node("CLI_HPC", "⌨️  Terminal (CLI)", shape="ellipse", style="filled", fillcolor="#438eac")

dot.node(
    "N_HPC_1", 
    "ℹ️  Nota sobre entornos HPC:\n\n"
    "🚫  Docker no suele estar permitido en clústeres por restricciones de seguridad → se utiliza Apptainer.\n"
    "🚫  Interfaces gráficas como Shiny no están disponibles en HPC → la ejecución debe hacerse por terminal (CLI).", 
    shape="note", 
    style="filled", 
    fontsize="40", 
    margin="1.2,0.8", 
    fontcolor="#000000", 
    fillcolor="#dadada"
)


# Formularios
dot.node("FORMULARIO_VISUAL", "📄  Formulario Visual (GUI)", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("FORMULARIO_SHELL", "📄  Formulario en Shell (CLI)", shape="ellipse", style="filled", fillcolor="#438eac")


# Selección del análisis
dot.node("D2", "🔬  ¿Qué tipo de análisis quiere hacer?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("A1", "🧬  Bulk RNA-Seq", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("A2", "🧫  Single-cell RNA-Seq", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("A3", "🌱  Metagenómica", shape="ellipse", style="filled", fillcolor="#438eac")


# Parámetros / Inputs
dot.node("PARAMS_A1", "⚙️  Configurar parámetros: Bulk RNA-Seq", shape="parallelogram", style="filled", margin="0.2,0.3", fillcolor="#297c71")
dot.node("PARAMS_A2", "⚙️  Configurar parámetros: Single-cell RNA-Seq", shape="parallelogram", style="filled", margin="0.2,0.3", fillcolor="#297c71")
dot.node("PARAMS_A3", "⚙️  Configurar parámetros: Metagenómica", shape="parallelogram", style="filled", margin="0.2,0.3", fillcolor="#297c71")


# Pipelines
dot.node("PIPELINE_A1", "🚀  Ejecutar pipeline: Bulk RNA-Seq", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("PIPELINE_A2", "🚀  Ejecutar pipeline: Single-cell RNA-Seq", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("PIPELINE_A3", "🚀  Ejecutar pipeline: Metagenómica", shape="ellipse", style="filled", fillcolor="#438eac")


# Reports
dot.node("REPORT_A1", "📊  Resultados interactivos: Bulk RNA-Seq", shape="box", style="filled", fontcolor="#000000", fontsize="50", margin="1.8,1", fillcolor="#e5cb3f")
dot.node("REPORT_A2", "📊  Resultados interactivos: Single-cell RNA-Seq", shape="box", style="filled", fontcolor="#000000", fontsize="50", margin="1.8,1", fillcolor="#e5cb3f")
dot.node("REPORT_A3", "📊  Resultados interactivos: Metagenómica", shape="box", style="filled", fontcolor="#000000", fontsize="50", margin="1.8,1", fillcolor="#e5cb3f")




#-----------------------------------------------------------------------------------------------------------------------------------
# EDGES
#-----------------------------------------------------------------------------------------------------------------------------------

# Conexiones principales
dot.edge("USUARIO", "D1")
dot.edge("D1", "LOCAL")
dot.edge("D1", "HPC")


# Local
dot.edge("LOCAL", "D_LOCAL_1")
dot.edge("D_LOCAL_1", "DIRECT_LOCAL")
dot.edge("D_LOCAL_1", "CONTENEDOR_LOCAL")

dot.edge("CONTENEDOR_LOCAL", "D_LOCAL_2")
dot.edge("D_LOCAL_2", "DOCKER_LOCAL")
dot.edge("D_LOCAL_2", "APPTAINER_LOCAL")

dot.edge("DIRECT_LOCAL", "D_LOCAL_3")
dot.edge("DOCKER_LOCAL", "D_LOCAL_3")
dot.edge("APPTAINER_LOCAL", "D_LOCAL_3")

dot.edge("D_LOCAL_3", "CLI_LOCAL")
dot.edge("D_LOCAL_3", "SHINY_LOCAL")


# HPC
dot.edge("HPC", "D_HPC_1")
dot.edge("D_HPC_1", "DIRECT_HPC")
dot.edge("D_HPC_1", "CONTENEDOR_HPC")

dot.edge("CONTENEDOR_HPC", "APPTAINER_HPC")

dot.edge("DIRECT_HPC", "CLI_HPC")
dot.edge("APPTAINER_HPC", "CLI_HPC")


# Formularios
dot.edge("SHINY_LOCAL", "FORMULARIO_VISUAL")
dot.edge("CLI_LOCAL", "FORMULARIO_SHELL")

dot.edge("CLI_HPC", "FORMULARIO_SHELL")


# Selección del tipo de análisis
dot.edge("FORMULARIO_VISUAL", "D2")
dot.edge("FORMULARIO_SHELL", "D2")

dot.edge("D2", "A1")
dot.edge("D2", "A2")
dot.edge("D2", "A3")


# Parámetros
dot.edge("A1", "PARAMS_A1")
dot.edge("A2", "PARAMS_A2")
dot.edge("A3", "PARAMS_A3")


# Pipelines
dot.edge("PARAMS_A1", "PIPELINE_A1")
dot.edge("PARAMS_A2", "PIPELINE_A2")
dot.edge("PARAMS_A3", "PIPELINE_A3")


# Reports
dot.edge("PIPELINE_A1", "REPORT_A1")
dot.edge("PIPELINE_A2", "REPORT_A2")
dot.edge("PIPELINE_A3", "REPORT_A3")


# Notas
dot.edge("USUARIO", "N1", style="dotted")
dot.edge("CLI_HPC", "N_HPC_1", style="dotted")




#-----------------------------------------------------------------------------------------------------------------------------------
# RENDER
#-----------------------------------------------------------------------------------------------------------------------------------

dot.render("general_workflow", view=True)
# Out:
# 'general_workflow.png'

# %% [markdown]
# $\ $
#
# $\ $
#
# $\ $
#
# <span style="color:#67bb74">
#
# ---
# ---
# ## **Estructura del diagrama de flujo para Bulk RNA-Seq**
# ---
# ---
#
# </span>

# %%
#-----------------------------------------------------------------------------------------------------------------------------------
# CONFIGURACIÓN DEL GRÁFICO
#-----------------------------------------------------------------------------------------------------------------------------------

dot = Digraph("Pipeline", format="png")
dot.attr(rankdir="TB", nodesep="2", ranksep="2", fontsize="45", pad="2", splines="true", bgcolor="#e1e4eb", dpi="400", size="10,6!")
dot.attr("node", fontsize="40", fontname="Helvetica-Bold", fontcolor="#FFFFFF", margin="1,0.6", style="filled", shape="oval", penwidth="4", fillcolor="#A8DADC")
dot.attr("edge", fontsize="15", color="#1D3557", penwidth="8", arrowhead="normal", fontcolor="#1D3557")




#-----------------------------------------------------------------------------------------------------------------------------------
# NODOS
#-----------------------------------------------------------------------------------------------------------------------------------

# Punto de partida
dot.node("USUARIO", "🧑  Usuario", shape="box", style="filled", fontsize="55", margin="1.8,1", fillcolor="#a23f5d")
dot.node("N1", "📁  Datos de entrada con los que elaborar el informe", shape="note", style="filled", fontsize="42", margin="1.2,0.6", fontcolor="#000000", fillcolor="#dadada")


# Primera decisión: Local vs HPC
dot.node("D1", "¿Dónde quiere ejecutar el análisis?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("LOCAL", "💻  Local", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("HPC", "🖥️  HPC / ☁️  Cloud (cluster)", shape="ellipse", style="filled", fillcolor="#438eac")


# Decisiones dentro de Local
dot.node("D_LOCAL_1", "⚙️  ¿Cómo quiere ejecutar en Local?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("DIRECT_LOCAL", "🖥️  Directo en su ordenador", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("CONTENEDOR_LOCAL", "📦  En un contenedor (recomendado)", shape="ellipse", style="filled", fillcolor="#438eac")

dot.node("D_LOCAL_2", "📦  ¿Qué contenedor usar?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("DOCKER_LOCAL", "🐳  Docker", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("APPTAINER_LOCAL", "🧪  Apptainer", shape="ellipse", style="filled", fillcolor="#438eac")

dot.node("D_LOCAL_3", "🛠️  ¿Cómo quiere interactuar?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("CLI_LOCAL", "⌨️  Terminal (CLI)", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("SHINY_LOCAL", "🖼️  Interfaz gráfica (Shiny)", shape="ellipse", style="filled", fillcolor="#438eac")


# Decisiones dentro HPC/Cloud
dot.node("D_HPC_1", "⚙️  ¿Cómo quiere ejecutar en HPC?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("DIRECT_HPC", "🖥️  Directo en el cluster", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("CONTENEDOR_HPC", "📦  En contenedor (recomendado)", shape="ellipse", style="filled", fillcolor="#438eac")

dot.node("APPTAINER_HPC", "🧪  Apptainer", shape="ellipse", style="filled", fillcolor="#438eac")

dot.node("CLI_HPC", "⌨️  Terminal (CLI)", shape="ellipse", style="filled", fillcolor="#438eac")

dot.node(
    "N_HPC_1", 
    "ℹ️  Nota sobre entornos HPC:\n\n"
    "🚫  Docker no suele estar permitido en clústeres por restricciones de seguridad → se utiliza Apptainer.\n"
    "🚫  Interfaces gráficas como Shiny no están disponibles en HPC → la ejecución debe hacerse por terminal (CLI).", 
    shape="note", 
    style="filled", 
    fontsize="40", 
    margin="1.2,0.8", 
    fontcolor="#000000", 
    fillcolor="#dadada"
)


# Formularios
dot.node("FORMULARIO_VISUAL", "📄  Formulario Visual (GUI)", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("FORMULARIO_SHELL", "📄  Formulario en Shell (CLI)", shape="ellipse", style="filled", fillcolor="#438eac")


# Selección del análisis
dot.node("D2", "🔬  ¿Qué tipo de análisis quiere hacer?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("A1", "🧬  Bulk RNA-Seq", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("A2", "🧫  Single-cell RNA-Seq", shape="ellipse", style="filled", fillcolor="#a6a6a6")
dot.node("A3", "🌱  Metagenómica", shape="ellipse", style="filled", fillcolor="#a6a6a6")


# Parámetros / Inputs
dot.node("PARAMS_A1", "⚙️  Configurar parámetros: Bulk RNA-Seq", shape="parallelogram", style="filled", margin="0.2,0.3", fillcolor="#297c71")
dot.node("PARAMS_A2", "⚙️  Configurar parámetros: Single-cell RNA-Seq", shape="parallelogram", style="filled", margin="0.2,0.3", fillcolor="#898989")
dot.node("PARAMS_A3", "⚙️  Configurar parámetros: Metagenómica", shape="parallelogram", style="filled", margin="0.2,0.3", fillcolor="#898989")


# Pipelines
dot.node("PIPELINE_A1", "🚀  Ejecutar pipeline: Bulk RNA-Seq", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("PIPELINE_A2", "🚀  Ejecutar pipeline: Single-cell RNA-Seq", shape="ellipse", style="filled", fillcolor="#a6a6a6")
dot.node("PIPELINE_A3", "🚀  Ejecutar pipeline: Metagenómica", shape="ellipse", style="filled", fillcolor="#a6a6a6")


# Reports
dot.node("REPORT_A1", "📊  Resultados interactivos: Bulk RNA-Seq", shape="box", style="filled", fontcolor="#000000", fontsize="50", margin="1.8,1", fillcolor="#e5cb3f")
dot.node("REPORT_A2", "📊  Resultados interactivos: Single-cell RNA-Seq", shape="box", style="filled", fontcolor="#000000", fontsize="50", margin="1.8,1", fillcolor="#bfbfbf")
dot.node("REPORT_A3", "📊  Resultados interactivos: Metagenómica", shape="box", style="filled", fontcolor="#000000", fontsize="50", margin="1.8,1", fillcolor="#bfbfbf")




#-----------------------------------------------------------------------------------------------------------------------------------
# EDGES
#-----------------------------------------------------------------------------------------------------------------------------------

# Conexiones principales
dot.edge("USUARIO", "D1")
dot.edge("D1", "LOCAL")
dot.edge("D1", "HPC")


# Local
dot.edge("LOCAL", "D_LOCAL_1")
dot.edge("D_LOCAL_1", "DIRECT_LOCAL")
dot.edge("D_LOCAL_1", "CONTENEDOR_LOCAL")

dot.edge("CONTENEDOR_LOCAL", "D_LOCAL_2")
dot.edge("D_LOCAL_2", "DOCKER_LOCAL")
dot.edge("D_LOCAL_2", "APPTAINER_LOCAL")

dot.edge("DIRECT_LOCAL", "D_LOCAL_3")
dot.edge("DOCKER_LOCAL", "D_LOCAL_3")
dot.edge("APPTAINER_LOCAL", "D_LOCAL_3")

dot.edge("D_LOCAL_3", "CLI_LOCAL")
dot.edge("D_LOCAL_3", "SHINY_LOCAL")


# HPC
dot.edge("HPC", "D_HPC_1")
dot.edge("D_HPC_1", "DIRECT_HPC")
dot.edge("D_HPC_1", "CONTENEDOR_HPC")

dot.edge("CONTENEDOR_HPC", "APPTAINER_HPC")

dot.edge("DIRECT_HPC", "CLI_HPC")
dot.edge("APPTAINER_HPC", "CLI_HPC")


# Formularios
dot.edge("SHINY_LOCAL", "FORMULARIO_VISUAL")
dot.edge("CLI_LOCAL", "FORMULARIO_SHELL")

dot.edge("CLI_HPC", "FORMULARIO_SHELL")


# Selección del tipo de análisis
dot.edge("FORMULARIO_VISUAL", "D2")
dot.edge("FORMULARIO_SHELL", "D2")

dot.edge("D2", "A1")
dot.edge("D2", "A2", color="#6A6A6A")
dot.edge("D2", "A3", color="#6A6A6A")


# Parámetros
dot.edge("A1", "PARAMS_A1")
dot.edge("A2", "PARAMS_A2", color="#6A6A6A")
dot.edge("A3", "PARAMS_A3", color="#6A6A6A")


# Pipelines
dot.edge("PARAMS_A1", "PIPELINE_A1")
dot.edge("PARAMS_A2", "PIPELINE_A2", color="#6A6A6A")
dot.edge("PARAMS_A3", "PIPELINE_A3", color="#6A6A6A")


# Reports
dot.edge("PIPELINE_A1", "REPORT_A1")
dot.edge("PIPELINE_A2", "REPORT_A2", color="#6A6A6A")
dot.edge("PIPELINE_A3", "REPORT_A3", color="#6A6A6A")


# Notas
dot.edge("USUARIO", "N1", style="dotted")
dot.edge("CLI_HPC", "N_HPC_1", style="dotted")




#-----------------------------------------------------------------------------------------------------------------------------------
# RENDER
#-----------------------------------------------------------------------------------------------------------------------------------

dot.render("bulk_rna_seq_workflow", view=True)
# Out:
# 'bulk_rna_seq_workflow.png'

# %% [markdown]
# $\ $
#
# $\ $
#
# $\ $
#
# <span style="color:#67bb74">
#
# ---
# ---
# ## **Estructura del diagrama de flujo para Single-cell RNA-Seq**
# ---
# ---
#
# </span>

# %%
#-----------------------------------------------------------------------------------------------------------------------------------
# CONFIGURACIÓN DEL GRÁFICO
#-----------------------------------------------------------------------------------------------------------------------------------

dot = Digraph("Pipeline", format="png")
dot.attr(rankdir="TB", nodesep="2", ranksep="2", fontsize="45", pad="2", splines="true", bgcolor="#e1e4eb", dpi="400", size="10,6!")
dot.attr("node", fontsize="40", fontname="Helvetica-Bold", fontcolor="#FFFFFF", margin="1,0.6", style="filled", shape="oval", penwidth="4", fillcolor="#A8DADC")
dot.attr("edge", fontsize="15", color="#1D3557", penwidth="8", arrowhead="normal", fontcolor="#1D3557")




#-----------------------------------------------------------------------------------------------------------------------------------
# NODOS
#-----------------------------------------------------------------------------------------------------------------------------------

# Punto de partida
dot.node("USUARIO", "🧑  Usuario", shape="box", style="filled", fontsize="55", margin="1.8,1", fillcolor="#a23f5d")
dot.node("N1", "📁  Datos de entrada con los que elaborar el informe", shape="note", style="filled", fontsize="42", margin="1.2,0.6", fontcolor="#000000", fillcolor="#dadada")


# Primera decisión: Local vs HPC
dot.node("D1", "¿Dónde quiere ejecutar el análisis?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("LOCAL", "💻  Local", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("HPC", "🖥️  HPC / ☁️  Cloud (cluster)", shape="ellipse", style="filled", fillcolor="#438eac")


# Decisiones dentro de Local
dot.node("D_LOCAL_1", "⚙️  ¿Cómo quiere ejecutar en Local?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("DIRECT_LOCAL", "🖥️  Directo en su ordenador", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("CONTENEDOR_LOCAL", "📦  En un contenedor (recomendado)", shape="ellipse", style="filled", fillcolor="#438eac")

dot.node("D_LOCAL_2", "📦  ¿Qué contenedor usar?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("DOCKER_LOCAL", "🐳  Docker", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("APPTAINER_LOCAL", "🧪  Apptainer", shape="ellipse", style="filled", fillcolor="#438eac")

dot.node("D_LOCAL_3", "🛠️  ¿Cómo quiere interactuar?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("CLI_LOCAL", "⌨️  Terminal (CLI)", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("SHINY_LOCAL", "🖼️  Interfaz gráfica (Shiny)", shape="ellipse", style="filled", fillcolor="#438eac")


# Decisiones dentro HPC/Cloud
dot.node("D_HPC_1", "⚙️  ¿Cómo quiere ejecutar en HPC?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("DIRECT_HPC", "🖥️  Directo en el cluster", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("CONTENEDOR_HPC", "📦  En contenedor (recomendado)", shape="ellipse", style="filled", fillcolor="#438eac")

dot.node("APPTAINER_HPC", "🧪  Apptainer", shape="ellipse", style="filled", fillcolor="#438eac")

dot.node("CLI_HPC", "⌨️  Terminal (CLI)", shape="ellipse", style="filled", fillcolor="#438eac")

dot.node(
    "N_HPC_1", 
    "ℹ️  Nota sobre entornos HPC:\n\n"
    "🚫  Docker no suele estar permitido en clústeres por restricciones de seguridad → se utiliza Apptainer.\n"
    "🚫  Interfaces gráficas como Shiny no están disponibles en HPC → la ejecución debe hacerse por terminal (CLI).", 
    shape="note", 
    style="filled", 
    fontsize="40", 
    margin="1.2,0.8", 
    fontcolor="#000000", 
    fillcolor="#dadada"
)


# Formularios
dot.node("FORMULARIO_VISUAL", "📄  Formulario Visual (GUI)", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("FORMULARIO_SHELL", "📄  Formulario en Shell (CLI)", shape="ellipse", style="filled", fillcolor="#438eac")


# Selección del análisis
dot.node("D2", "🔬  ¿Qué tipo de análisis quiere hacer?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("A1", "🧬  Bulk RNA-Seq", shape="ellipse", style="filled", fillcolor="#a6a6a6")
dot.node("A2", "🧫  Single-cell RNA-Seq", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("A3", "🌱  Metagenómica", shape="ellipse", style="filled", fillcolor="#a6a6a6")


# Parámetros / Inputs
dot.node("PARAMS_A1", "⚙️  Configurar parámetros: Bulk RNA-Seq", shape="parallelogram", style="filled", margin="0.2,0.3", fillcolor="#898989")
dot.node("PARAMS_A2", "⚙️  Configurar parámetros: Single-cell RNA-Seq", shape="parallelogram", style="filled", margin="0.2,0.3", fillcolor="#297c71")
dot.node("PARAMS_A3", "⚙️  Configurar parámetros: Metagenómica", shape="parallelogram", style="filled", margin="0.2,0.3", fillcolor="#898989")


# Pipelines
dot.node("PIPELINE_A1", "🚀  Ejecutar pipeline: Bulk RNA-Seq", shape="ellipse", style="filled", fillcolor="#a6a6a6")
dot.node("PIPELINE_A2", "🚀  Ejecutar pipeline: Single-cell RNA-Seq", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("PIPELINE_A3", "🚀  Ejecutar pipeline: Metagenómica", shape="ellipse", style="filled", fillcolor="#a6a6a6")


# Reports
dot.node("REPORT_A1", "📊  Resultados interactivos: Bulk RNA-Seq", shape="box", style="filled", fontcolor="#000000", fontsize="50", margin="1.8,1", fillcolor="#bfbfbf")
dot.node("REPORT_A2", "📊  Resultados interactivos: Single-cell RNA-Seq", shape="box", style="filled", fontcolor="#000000", fontsize="50", margin="1.8,1", fillcolor="#e5cb3f")
dot.node("REPORT_A3", "📊  Resultados interactivos: Metagenómica", shape="box", style="filled", fontcolor="#000000", fontsize="50", margin="1.8,1", fillcolor="#bfbfbf")




#-----------------------------------------------------------------------------------------------------------------------------------
# EDGES
#-----------------------------------------------------------------------------------------------------------------------------------

# Conexiones principales
dot.edge("USUARIO", "D1")
dot.edge("D1", "LOCAL")
dot.edge("D1", "HPC")


# Local
dot.edge("LOCAL", "D_LOCAL_1")
dot.edge("D_LOCAL_1", "DIRECT_LOCAL")
dot.edge("D_LOCAL_1", "CONTENEDOR_LOCAL")

dot.edge("CONTENEDOR_LOCAL", "D_LOCAL_2")
dot.edge("D_LOCAL_2", "DOCKER_LOCAL")
dot.edge("D_LOCAL_2", "APPTAINER_LOCAL")

dot.edge("DIRECT_LOCAL", "D_LOCAL_3")
dot.edge("DOCKER_LOCAL", "D_LOCAL_3")
dot.edge("APPTAINER_LOCAL", "D_LOCAL_3")

dot.edge("D_LOCAL_3", "CLI_LOCAL")
dot.edge("D_LOCAL_3", "SHINY_LOCAL")


# HPC
dot.edge("HPC", "D_HPC_1")
dot.edge("D_HPC_1", "DIRECT_HPC")
dot.edge("D_HPC_1", "CONTENEDOR_HPC")

dot.edge("CONTENEDOR_HPC", "APPTAINER_HPC")

dot.edge("DIRECT_HPC", "CLI_HPC")
dot.edge("APPTAINER_HPC", "CLI_HPC")


# Formularios
dot.edge("SHINY_LOCAL", "FORMULARIO_VISUAL")
dot.edge("CLI_LOCAL", "FORMULARIO_SHELL")

dot.edge("CLI_HPC", "FORMULARIO_SHELL")


# Selección del tipo de análisis
dot.edge("FORMULARIO_VISUAL", "D2")
dot.edge("FORMULARIO_SHELL", "D2")

dot.edge("D2", "A1", color="#6A6A6A")
dot.edge("D2", "A2")
dot.edge("D2", "A3", color="#6A6A6A")


# Parámetros
dot.edge("A1", "PARAMS_A1", color="#6A6A6A")
dot.edge("A2", "PARAMS_A2")
dot.edge("A3", "PARAMS_A3", color="#6A6A6A")


# Pipelines
dot.edge("PARAMS_A1", "PIPELINE_A1", color="#6A6A6A")
dot.edge("PARAMS_A2", "PIPELINE_A2")
dot.edge("PARAMS_A3", "PIPELINE_A3", color="#6A6A6A")


# Reports
dot.edge("PIPELINE_A1", "REPORT_A1", color="#6A6A6A")
dot.edge("PIPELINE_A2", "REPORT_A2")
dot.edge("PIPELINE_A3", "REPORT_A3", color="#6A6A6A")


# Notas
dot.edge("USUARIO", "N1", style="dotted")
dot.edge("CLI_HPC", "N_HPC_1", style="dotted")




#-----------------------------------------------------------------------------------------------------------------------------------
# RENDER
#-----------------------------------------------------------------------------------------------------------------------------------

dot.render("sc_rna_seq_workflow", view=True)
# Out:
# 'sc_rna_seq_workflow.png'

# %% [markdown]
# $\ $
#
# $\ $
#
# $\ $
#
# <span style="color:#67bb74">
#
# ---
# ---
# ## **Estructura del diagrama de flujo para Metagenómica**
# ---
# ---
#
# </span>

# %%
#-----------------------------------------------------------------------------------------------------------------------------------
# CONFIGURACIÓN DEL GRÁFICO
#-----------------------------------------------------------------------------------------------------------------------------------

dot = Digraph("Pipeline", format="png")
dot.attr(rankdir="TB", nodesep="2", ranksep="2", fontsize="45", pad="2", splines="true", bgcolor="#e1e4eb", dpi="400", size="10,6!")
dot.attr("node", fontsize="40", fontname="Helvetica-Bold", fontcolor="#FFFFFF", margin="1,0.6", style="filled", shape="oval", penwidth="4", fillcolor="#A8DADC")
dot.attr("edge", fontsize="15", color="#1D3557", penwidth="8", arrowhead="normal", fontcolor="#1D3557")




#-----------------------------------------------------------------------------------------------------------------------------------
# NODOS
#-----------------------------------------------------------------------------------------------------------------------------------

# Punto de partida
dot.node("USUARIO", "🧑  Usuario", shape="box", style="filled", fontsize="55", margin="1.8,1", fillcolor="#a23f5d")
dot.node("N1", "📁  Datos de entrada con los que elaborar el informe", shape="note", style="filled", fontsize="42", margin="1.2,0.6", fontcolor="#000000", fillcolor="#dadada")


# Primera decisión: Local vs HPC
dot.node("D1", "¿Dónde quiere ejecutar el análisis?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("LOCAL", "💻  Local", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("HPC", "🖥️  HPC / ☁️  Cloud (cluster)", shape="ellipse", style="filled", fillcolor="#438eac")


# Decisiones dentro de Local
dot.node("D_LOCAL_1", "⚙️  ¿Cómo quiere ejecutar en Local?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("DIRECT_LOCAL", "🖥️  Directo en su ordenador", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("CONTENEDOR_LOCAL", "📦  En un contenedor (recomendado)", shape="ellipse", style="filled", fillcolor="#438eac")

dot.node("D_LOCAL_2", "📦  ¿Qué contenedor usar?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("DOCKER_LOCAL", "🐳  Docker", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("APPTAINER_LOCAL", "🧪  Apptainer", shape="ellipse", style="filled", fillcolor="#438eac")

dot.node("D_LOCAL_3", "🛠️  ¿Cómo quiere interactuar?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("CLI_LOCAL", "⌨️  Terminal (CLI)", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("SHINY_LOCAL", "🖼️  Interfaz gráfica (Shiny)", shape="ellipse", style="filled", fillcolor="#438eac")


# Decisiones dentro HPC/Cloud
dot.node("D_HPC_1", "⚙️  ¿Cómo quiere ejecutar en HPC?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("DIRECT_HPC", "🖥️  Directo en el cluster", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("CONTENEDOR_HPC", "📦  En contenedor (recomendado)", shape="ellipse", style="filled", fillcolor="#438eac")

dot.node("APPTAINER_HPC", "🧪  Apptainer", shape="ellipse", style="filled", fillcolor="#438eac")

dot.node("CLI_HPC", "⌨️  Terminal (CLI)", shape="ellipse", style="filled", fillcolor="#438eac")

dot.node(
    "N_HPC_1", 
    "ℹ️  Nota sobre entornos HPC:\n\n"
    "🚫  Docker no suele estar permitido en clústeres por restricciones de seguridad → se utiliza Apptainer.\n"
    "🚫  Interfaces gráficas como Shiny no están disponibles en HPC → la ejecución debe hacerse por terminal (CLI).", 
    shape="note", 
    style="filled", 
    fontsize="40", 
    margin="1.2,0.8", 
    fontcolor="#000000", 
    fillcolor="#dadada"
)


# Formularios
dot.node("FORMULARIO_VISUAL", "📄  Formulario Visual (GUI)", shape="ellipse", style="filled", fillcolor="#438eac")
dot.node("FORMULARIO_SHELL", "📄  Formulario en Shell (CLI)", shape="ellipse", style="filled", fillcolor="#438eac")


# Selección del análisis
dot.node("D2", "🔬  ¿Qué tipo de análisis quiere hacer?", shape="diamond", style="filled", fillcolor="#2c4b7b")
dot.node("A1", "🧬  Bulk RNA-Seq", shape="ellipse", style="filled", fillcolor="#a6a6a6")
dot.node("A2", "🧫  Single-cell RNA-Seq", shape="ellipse", style="filled", fillcolor="#a6a6a6")
dot.node("A3", "🌱  Metagenómica", shape="ellipse", style="filled", fillcolor="#438eac")


# Parámetros / Inputs
dot.node("PARAMS_A1", "⚙️  Configurar parámetros: Bulk RNA-Seq", shape="parallelogram", style="filled", margin="0.2,0.3", fillcolor="#898989")
dot.node("PARAMS_A2", "⚙️  Configurar parámetros: Single-cell RNA-Seq", shape="parallelogram", style="filled", margin="0.2,0.3", fillcolor="#898989")
dot.node("PARAMS_A3", "⚙️  Configurar parámetros: Metagenómica", shape="parallelogram", style="filled", margin="0.2,0.3", fillcolor="#297c71")


# Pipelines
dot.node("PIPELINE_A1", "🚀  Ejecutar pipeline: Bulk RNA-Seq", shape="ellipse", style="filled", fillcolor="#a6a6a6")
dot.node("PIPELINE_A2", "🚀  Ejecutar pipeline: Single-cell RNA-Seq", shape="ellipse", style="filled", fillcolor="#a6a6a6")
dot.node("PIPELINE_A3", "🚀  Ejecutar pipeline: Metagenómica", shape="ellipse", style="filled", fillcolor="#438eac")


# Reports
dot.node("REPORT_A1", "📊  Resultados interactivos: Bulk RNA-Seq", shape="box", style="filled", fontcolor="#000000", fontsize="50", margin="1.8,1", fillcolor="#bfbfbf")
dot.node("REPORT_A2", "📊  Resultados interactivos: Single-cell RNA-Seq", shape="box", style="filled", fontcolor="#000000", fontsize="50", margin="1.8,1", fillcolor="#bfbfbf")
dot.node("REPORT_A3", "📊  Resultados interactivos: Metagenómica", shape="box", style="filled", fontcolor="#000000", fontsize="50", margin="1.8,1", fillcolor="#e5cb3f")




#-----------------------------------------------------------------------------------------------------------------------------------
# EDGES
#-----------------------------------------------------------------------------------------------------------------------------------

# Conexiones principales
dot.edge("USUARIO", "D1")
dot.edge("D1", "LOCAL")
dot.edge("D1", "HPC")


# Local
dot.edge("LOCAL", "D_LOCAL_1")
dot.edge("D_LOCAL_1", "DIRECT_LOCAL")
dot.edge("D_LOCAL_1", "CONTENEDOR_LOCAL")

dot.edge("CONTENEDOR_LOCAL", "D_LOCAL_2")
dot.edge("D_LOCAL_2", "DOCKER_LOCAL")
dot.edge("D_LOCAL_2", "APPTAINER_LOCAL")

dot.edge("DIRECT_LOCAL", "D_LOCAL_3")
dot.edge("DOCKER_LOCAL", "D_LOCAL_3")
dot.edge("APPTAINER_LOCAL", "D_LOCAL_3")

dot.edge("D_LOCAL_3", "CLI_LOCAL")
dot.edge("D_LOCAL_3", "SHINY_LOCAL")


# HPC
dot.edge("HPC", "D_HPC_1")
dot.edge("D_HPC_1", "DIRECT_HPC")
dot.edge("D_HPC_1", "CONTENEDOR_HPC")

dot.edge("CONTENEDOR_HPC", "APPTAINER_HPC")

dot.edge("DIRECT_HPC", "CLI_HPC")
dot.edge("APPTAINER_HPC", "CLI_HPC")


# Formularios
dot.edge("SHINY_LOCAL", "FORMULARIO_VISUAL")
dot.edge("CLI_LOCAL", "FORMULARIO_SHELL")

dot.edge("CLI_HPC", "FORMULARIO_SHELL")


# Selección del tipo de análisis
dot.edge("FORMULARIO_VISUAL", "D2")
dot.edge("FORMULARIO_SHELL", "D2")

dot.edge("D2", "A1", color="#6A6A6A")
dot.edge("D2", "A2", color="#6A6A6A")
dot.edge("D2", "A3")


# Parámetros
dot.edge("A1", "PARAMS_A1", color="#6A6A6A")
dot.edge("A2", "PARAMS_A2", color="#6A6A6A")
dot.edge("A3", "PARAMS_A3")


# Pipelines
dot.edge("PARAMS_A1", "PIPELINE_A1", color="#6A6A6A")
dot.edge("PARAMS_A2", "PIPELINE_A2", color="#6A6A6A")
dot.edge("PARAMS_A3", "PIPELINE_A3")


# Reports
dot.edge("PIPELINE_A1", "REPORT_A1", color="#6A6A6A")
dot.edge("PIPELINE_A2", "REPORT_A2", color="#6A6A6A")
dot.edge("PIPELINE_A3", "REPORT_A3")


# Notas
dot.edge("USUARIO", "N1", style="dotted")
dot.edge("CLI_HPC", "N_HPC_1", style="dotted")




#-----------------------------------------------------------------------------------------------------------------------------------
# RENDER
#-----------------------------------------------------------------------------------------------------------------------------------

dot.render("metagenomic_workflow", view=True)
# Out:
# 'metagenomic_workflow.png'
